# %%
# import warnings
# warnings.filterwarnings("ignore")
# import h5py
# from keras.models import load_model

# from backgroundRemove import backgroundRemoval
# from coloranalysis import get_colors
# from DeepLearning import *

# img = 'images/tshirt.jpeg'
# get_colors(backgroundRemoval(img),3,True)
# FashionClassification(backgroundRemoval(img))

# %%
# %config Completer.use_jedi = False

# %%
from ImageOutput import *

# %%
img = 'images/appleT.webp'
ImageDetails(img)
# Out:
# --------------------
# Type of fashion: Topwear Shirts
# Brand: Heineken

# %%
img = 'images/nikeT.webp'
ImageDetails(img)
# Out:
# --------------------
# Type of fashion: Topwear Tshirts
# Brand: Nike
