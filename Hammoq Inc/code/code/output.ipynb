# %%
import warnings
warnings.filterwarnings("ignore")
from backgroundRemove import backgroundRemoval
from coloranalysis import get_colors
from keras.models import load_model

# %%
img = 'images/tshirt.jpeg'

# %%
get_colors(backgroundRemoval(img),3,True)

# %%
model = load_model("../../model/fashion_classification.h5")
def predict(imgPath):
    img = cv2.imread(imgPath)
    plt.imshow(img)
    img.resize((TARGET_SIZE, TARGET_SIZE,3))
    image = np.expand_dims(img, axis=0)
    pred = model.predict(image)
    plt.title(classes[np.argmax(pred)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-1867305d2b11> in <module>
# ----> 1 model = load_model("../../model/fashion_classification.h5")
#
# ~/opt/anaconda3/envs/unity/lib/python3.6/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~/opt/anaconda3/envs/unity/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
# ...
