# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
import os

# %%
os.chdir("../data/TEST")

# %%
ls
# Out:
# 1785NL01_2.webp  bag3.jpeg        shirt.webp       watch.webp
# bag.png          download.jpeg    tshirt.png
# bag2.jpg         shirt.png        watch.jpg
